# %% [markdown]
# # Execute the code below

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
from sklearn.linear_model import LinearRegression
link = "https://raw.githubusercontent.com/murpi/wilddata/master/quests/weather2019.csv"
df_weather = pd.read_csv(link)

# %%
df_weather
# Out:
#            DATE  MAX_TEMPERATURE_C  MIN_TEMPERATURE_C  WINDSPEED_MAX_KMH  \
# 0    2019-01-01                  9                  4                 10
# 1    2019-01-02                  8                  5                 18
# 2    2019-01-03                  6                  0                 18
# 3    2019-01-04                  5                 -1                 15
# 4    2019-01-05                  6                 -1                  8
# ..          ...                ...                ...                ...
# 360  2019-12-27                 13                 10                 13
# 361  2019-12-28                 11                  5                 12
# 362  2019-12-29                  9                  2                 11
# 363  2019-12-30                 12                  4                  7
# 364  2019-12-31                 10                  4                 13
#
#      TEMPERATURE_MORNING_C  TEMPERATURE_NOON_C  TEMPERATURE_EVENING_C  \
# 0                        4                   7                      8
# 1                        7                   7                      5
# 2                        0                   4                      3
# 3                       -1                   4                      3
# 4                       -1                   4                      3
# ..                     ...                 ...                    ...
# 360                     10                  12                     11
# 361                      7                   8                      8
# 362                      3                   6                      7
# 363                      5                   9                      9
# 364                      4                   7                      9
#
#      PRECIP_TOTAL_DAY_MM  HUMIDITY_MAX_PERCENT  VISIBILITY_AVG_KM  ...  \
# 0                    0.2                    94              9.000  ...
# 1                    0.0                    90              9.000  ...
# 2                    0.0                    88             10.000  ...
# 3                    0.0                    91             10.000  ...
# 4                    0.0                    91              8.000  ...
# ..                   ...                   ...                ...  ...
# 360                  0.0                    96              7.375  ...
# 361                  0.0                    93              7.625  ...
# 362                  0.0                    86             10.000  ...
# 363                  0.0                    61             10.000  ...
# 364                  0.1                    94              9.000  ...
#
#      WINDTEMP_MAX_C  WEATHER_CODE_MORNING  WEATHER_CODE_NOON  \
# 0                 3                   116                143
# 1                 3                   119                116
# 2                -4                   116                116
# 3                -4                   116                116
# 4                -2                   143                116
# ..              ...                   ...                ...
# 360               8                   119                143
# 361               4                   143                116
# 362               0                   116                116
# 363               4                   113                113
# 364               1                   113                143
#
#      WEATHER_CODE_EVENING  TOTAL_SNOW_MM  UV_INDEX  SUNHOUR           OPINION  \
# 0                     176              0         1      5.1          very bad
# 1                     116              0         1      8.7          very bad
# 2                     116              0         1      8.7          very bad
# 3                     122              0         1      5.1          very bad
# 4                     116              0         1      8.7          very bad
# ..                    ...            ...       ...      ...               ...
# 360                   116              0         1      8.7  not good not bad
# 361                   116              0         1      6.9          very bad
# 362                   116              0         1      8.7          very bad
# 363                   113              0         1      8.7          very bad
# 364                   119              0         1      8.7          very bad
#
#      MONTH  DAY
# 0        1    1
# 1        1    2
# 2        1    3
# 3        1    4
# 4        1    5
# ..     ...  ...
# 360     12   27
# 361     12   28
# 362     12   29
# 363     12   30
# 364     12   31
#
# [365 rows x 24 columns]

# %%
df_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   DATE                    365 non-null    object
#  1   MAX_TEMPERATURE_C       365 non-null    int64
#  2   MIN_TEMPERATURE_C       365 non-null    int64
#  3   WINDSPEED_MAX_KMH       365 non-null    int64
#  4   TEMPERATURE_MORNING_C   365 non-null    int64
#  5   TEMPERATURE_NOON_C      365 non-null    int64
#  6   TEMPERATURE_EVENING_C   365 non-null    int64
#  7   PRECIP_TOTAL_DAY_MM     365 non-null    float64
#  8   HUMIDITY_MAX_PERCENT    365 non-null    int64
#  9   VISIBILITY_AVG_KM       365 non-null    float64
#  10  PRESSURE_MAX_MB         365 non-null    int64
#  11  CLOUDCOVER_AVG_PERCENT  365 non-null    float64
#  12  HEATINDEX_MAX_C         365 non-null    int64
#  13  DEWPOINT_MAX_C          365 non-null    int64
#  14  WINDTEMP_MAX_C          365 non-null    int64
#  15  WEATHER_CODE_MORNING    365 non-null    int64
#  16  WEATHER_CODE_NOON       365 non-null    int64
#  17  WEATHER_CODE_EVENING    365 non-null    int64
#  18  TOTAL_SNOW_MM           365 non-null    int64
#  19  UV_INDEX                365 non-null    int64
#  20  SUNHOUR                 365 non-null    float64
#  21  OPINION                 365 non-null    object
#  22  MONTH                   365 non-null    int64
#  23  DAY                     365 non-null    int64
# dtypes: float64(4), int64(18), object(2)
# memory usage: 68.6+ KB

# %% [markdown]
# # Scoring and metrics
# Last time, you did a multivariate linear regression. But how can you be sure this multivariate linear regression is better than an univariate ? You have to measure it !

# %% [markdown]
# ## First regression
# Let's begin with a first linear regression : create a new column `'predict_from_sun'` whith the prediction of MAX temperature from the SUNHOUR variable.

# %%
# Your code here :
X = df_weather[['SUNHOUR']]
y = df_weather['MAX_TEMPERATURE_C']
model_from_sun1 = LinearRegression().fit(X, y)


df_weather['PREDICT_FROM_SUN'] = model_from_sun1.predict(df_weather[['SUNHOUR']])

# %%
df_weather
# Out:
#            DATE  MAX_TEMPERATURE_C  MIN_TEMPERATURE_C  WINDSPEED_MAX_KMH  \
# 0    2019-01-01                  9                  4                 10
# 1    2019-01-02                  8                  5                 18
# 2    2019-01-03                  6                  0                 18
# 3    2019-01-04                  5                 -1                 15
# 4    2019-01-05                  6                 -1                  8
# ..          ...                ...                ...                ...
# 360  2019-12-27                 13                 10                 13
# 361  2019-12-28                 11                  5                 12
# 362  2019-12-29                  9                  2                 11
# 363  2019-12-30                 12                  4                  7
# 364  2019-12-31                 10                  4                 13
#
#      TEMPERATURE_MORNING_C  TEMPERATURE_NOON_C  TEMPERATURE_EVENING_C  \
# 0                        4                   7                      8
# 1                        7                   7                      5
# 2                        0                   4                      3
# 3                       -1                   4                      3
# 4                       -1                   4                      3
# ..                     ...                 ...                    ...
# 360                     10                  12                     11
# 361                      7                   8                      8
# 362                      3                   6                      7
# 363                      5                   9                      9
# 364                      4                   7                      9
#
#      PRECIP_TOTAL_DAY_MM  HUMIDITY_MAX_PERCENT  VISIBILITY_AVG_KM  ...  \
# 0                    0.2                    94              9.000  ...
# 1                    0.0                    90              9.000  ...
# 2                    0.0                    88             10.000  ...
# 3                    0.0                    91             10.000  ...
# 4                    0.0                    91              8.000  ...
# ..                   ...                   ...                ...  ...
# 360                  0.0                    96              7.375  ...
# 361                  0.0                    93              7.625  ...
# 362                  0.0                    86             10.000  ...
# 363                  0.0                    61             10.000  ...
# 364                  0.1                    94              9.000  ...
#
#      WEATHER_CODE_MORNING  WEATHER_CODE_NOON  WEATHER_CODE_EVENING  \
# 0                     116                143                   176
# 1                     119                116                   116
# 2                     116                116                   116
# 3                     116                116                   122
# 4                     143                116                   116
# ..                    ...                ...                   ...
# 360                   119                143                   116
# 361                   143                116                   116
# 362                   116                116                   116
# 363                   113                113                   113
# 364                   113                143                   119
#
#      TOTAL_SNOW_MM  UV_INDEX  SUNHOUR           OPINION  MONTH  DAY  \
# 0                0         1      5.1          very bad      1    1
# 1                0         1      8.7          very bad      1    2
# 2                0         1      8.7          very bad      1    3
# 3                0         1      5.1          very bad      1    4
# 4                0         1      8.7          very bad      1    5
# ..             ...       ...      ...               ...    ...  ...
# 360              0         1      8.7  not good not bad     12   27
# 361              0         1      6.9          very bad     12   28
# 362              0         1      8.7          very bad     12   29
# 363              0         1      8.7          very bad     12   30
# 364              0         1      8.7          very bad     12   31
#
#      PREDICT_FROM_SUN
# 0           11.396823
# 1           16.020019
# 2           16.020019
# 3           11.396823
# 4           16.020019
# ..                ...
# 360         16.020019
# 361         13.708421
# 362         16.020019
# 363         16.020019
# 364         16.020019
#
# [365 rows x 25 columns]

# %% [markdown]
# ## R2 score
# The best possible R2 score is '1', when our prediction predicts perfectly the reality. Let's see what is our R2 score :

# %%
# Change the name of the model if it's necessary
model_from_sun1.score(X, y)
# Out:
# 0.47654554059087306

# %% [markdown]
# ## Let's continue with 2 others regressions
# - Second regression : create a new column 'predict_from_min' whith the prediction of MAX temperature from the MIN temperature variable
# - Third regression : create a new column 'predict_from_both' whith the prediction of MAX temperature from the both variables (MIN temperature and Sunhours)

# %%
# Your code here :

X_2 = df_weather[['MIN_TEMPERATURE_C']]
y_2 = df_weather['MAX_TEMPERATURE_C']
model_from_sun2 = LinearRegression().fit(X_2, y_2)

df_weather['PREDICT_FROM_MIN'] = model_from_sun2.predict(df_weather[['MIN_TEMPERATURE_C']])

# %%
X_3 = df_weather[['PREDICT_FROM_SUN', 'PREDICT_FROM_MIN']]
y_3 = df_weather['MAX_TEMPERATURE_C']
model_from_sun3 = LinearRegression().fit(X_3, y_3)

df_weather['PREDICT_FROM_BOTH'] = model_from_sun3.predict(df_weather[['PREDICT_FROM_SUN', 'PREDICT_FROM_MIN']])

# %%
df_weather
# Out:
#            DATE  MAX_TEMPERATURE_C  MIN_TEMPERATURE_C  WINDSPEED_MAX_KMH  \
# 0    2019-01-01                  9                  4                 10
# 1    2019-01-02                  8                  5                 18
# 2    2019-01-03                  6                  0                 18
# 3    2019-01-04                  5                 -1                 15
# 4    2019-01-05                  6                 -1                  8
# ..          ...                ...                ...                ...
# 360  2019-12-27                 13                 10                 13
# 361  2019-12-28                 11                  5                 12
# 362  2019-12-29                  9                  2                 11
# 363  2019-12-30                 12                  4                  7
# 364  2019-12-31                 10                  4                 13
#
#      TEMPERATURE_MORNING_C  TEMPERATURE_NOON_C  TEMPERATURE_EVENING_C  \
# 0                        4                   7                      8
# 1                        7                   7                      5
# 2                        0                   4                      3
# 3                       -1                   4                      3
# 4                       -1                   4                      3
# ..                     ...                 ...                    ...
# 360                     10                  12                     11
# 361                      7                   8                      8
# 362                      3                   6                      7
# 363                      5                   9                      9
# 364                      4                   7                      9
#
#      PRECIP_TOTAL_DAY_MM  HUMIDITY_MAX_PERCENT  VISIBILITY_AVG_KM  ...  \
# 0                    0.2                    94              9.000  ...
# 1                    0.0                    90              9.000  ...
# 2                    0.0                    88             10.000  ...
# 3                    0.0                    91             10.000  ...
# 4                    0.0                    91              8.000  ...
# ..                   ...                   ...                ...  ...
# 360                  0.0                    96              7.375  ...
# 361                  0.0                    93              7.625  ...
# 362                  0.0                    86             10.000  ...
# 363                  0.0                    61             10.000  ...
# 364                  0.1                    94              9.000  ...
#
#      WEATHER_CODE_EVENING  TOTAL_SNOW_MM  UV_INDEX  SUNHOUR           OPINION  \
# 0                     176              0         1      5.1          very bad
# 1                     116              0         1      8.7          very bad
# 2                     116              0         1      8.7          very bad
# 3                     122              0         1      5.1          very bad
# 4                     116              0         1      8.7          very bad
# ..                    ...            ...       ...      ...               ...
# 360                   116              0         1      8.7  not good not bad
# 361                   116              0         1      6.9          very bad
# 362                   116              0         1      8.7          very bad
# 363                   113              0         1      8.7          very bad
# 364                   119              0         1      8.7          very bad
#
#      MONTH  DAY  PREDICT_FROM_SUN  PREDICT_FROM_MIN  PREDICT_FROM_BOTH
# 0        1    1         11.396823         10.579999           8.980922
# 1        1    2         16.020019         11.802741          12.353602
# 2        1    3         16.020019          5.689031           7.410233
# 3        1    4         11.396823          4.466289           4.037552
# 4        1    5         16.020019          4.466289           6.421559
# ..     ...  ...               ...               ...                ...
# 360     12   27         16.020019         17.916452          17.296971
# 361     12   28         13.708421         11.802741          11.161599
# 362     12   29         16.020019          8.134515           9.387580
# 363     12   30         16.020019         10.579999          11.364928
# 364     12   31         16.020019         10.579999          11.364928
#
# [365 rows x 27 columns]

# %% [markdown]
# ## Calculate the R2 score of the 2 new predictions
# Be careful : if you still use the same "X" name, you will overwrite it.
#
# Which model has the best score ? Do you think it's logical ?

# %%
# Your code here :
model_from_sun3.score(X_3,y_3)
# Out:
# 0.8674787980774968

# %%
model_from_sun2.score(X_2,y_2)
# Out:
# 0.7689396999057355

# %% [markdown]
# # Train Test Split
# One of biggest problems of Machine learning is : **overfitting**.

# %% [markdown]
# To be sure that machine didn't memorize the result, we use the Train Test Split methodology. We keep some data separate (often 25% of our initial dataset). Then we train our model on the 75% (the "Train set").
# After, we can calculate a score on the "Test set".
#
# Let's do that !

# %%
# Juste read and execute the code below
from sklearn.model_selection import train_test_split

X = df_weather[['SUNHOUR']]
y = df_weather['MAX_TEMPERATURE_C']

# Here, we split our 2 datasets (the variables "X" and the target "y") into 4 datasets X and y for the train set and X and y for the test set.
# We set the size of the train set to 75%. And the rest is for the test set.
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, train_size = 0.75)
print("The length of the initial dataset is :", len(X))
print("The length of the train dataset is   :", len(X_train))
print("The length of the test dataset is    :", len(X_test))

# Here we train the model only on the train dataset.
newmodel = LinearRegression().fit(X_train, y_train)

# And now we compare both scores :
print("\nScore for the Train dataset :", newmodel.score(X_train, y_train))
print("Score for the Test dataset :", newmodel.score(X_test, y_test))
# Out:
# The length of the initial dataset is : 365
# The length of the train dataset is   : 273
# The length of the test dataset is    : 92
#
# Score for the Train dataset : 0.47243569075679914
# Score for the Test dataset : 0.4749360350733982

# %% [markdown]
# ## Both scores are very close, there is no overfitting, well done !
#
# What happens if we don't randomize our dataset. Here, the model learns only on the 9 first months.

# %%
# Juste read and execute the code below
from sklearn.model_selection import train_test_split

X = df_weather[['MIN_TEMPERATURE_C']]
y = df_weather['MAX_TEMPERATURE_C']

# We set the size of the train set to 75%. And the rest is for the test set.
# We set the split NOT in random.
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.75, shuffle = False)


# Here we train the model only on the train dataset.
newmodel = LinearRegression().fit(X_train, y_train)

# And now we compare both scores :
print("\nScore for the Train dataset :", newmodel.score(X_train, y_train))
print("Score for the Test dataset :", newmodel.score(X_test, y_test))
# Out:
# Score for the Train dataset : 0.7875765302008688
# Score for the Test dataset : 0.03610833322378593

# %% [markdown]
# ## There is an overfitting !
# Indeed, the model get a good score on the Train dataset, because he learned in winter / spring / summer datas. But he gets a bad score in Falls...

# %% [markdown]
# # Let's play !
# Train a new model with all numeric variables (without your target of course) and try to have a better score than previously.
#
# Remember to split randomly your dataset before training your model.
#
# Display the Test score.

# %%
# Your code here :

types = df_weather.dtypes
types
column = types[types.values != 'object'].index
column
liste_finale=[]
for i in column :
  if i != 'MAX_TEMPERATURE_C' and i != 'PREDICT_FROM_SUN	' and i != 'PREDICT_FROM_MIN' and i!= 'PREDICT_FROM_BOTH':
    liste_finale.append(i)
print(liste_finale)
# Out:
# ['MIN_TEMPERATURE_C', 'WINDSPEED_MAX_KMH', 'TEMPERATURE_MORNING_C', 'TEMPERATURE_NOON_C', 'TEMPERATURE_EVENING_C', 'PRECIP_TOTAL_DAY_MM', 'HUMIDITY_MAX_PERCENT', 'VISIBILITY_AVG_KM', 'PRESSURE_MAX_MB', 'CLOUDCOVER_AVG_PERCENT', 'HEATINDEX_MAX_C', 'DEWPOINT_MAX_C', 'WINDTEMP_MAX_C', 'WEATHER_CODE_MORNING', 'WEATHER_CODE_NOON', 'WEATHER_CODE_EVENING', 'TOTAL_SNOW_MM', 'UV_INDEX', 'SUNHOUR', 'MONTH', 'DAY', 'PREDICT_FROM_SUN']

# %%
X =df_weather[liste_finale]
y = df_weather['MAX_TEMPERATURE_C']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, train_size = 0.75)
newmodel1 = LinearRegression().fit(X_train, y_train)

print("\nScore for the Train dataset :", newmodel1.score(X_train, y_train))
print("Score for the Test dataset :", newmodel1.score(X_test, y_test))
# Out:
# Score for the Train dataset : 0.9933353831340123
# Score for the Test dataset : 0.9953728575100915

# %%
df_weather['PREDICT3'] = newmodel1.predict(df_weather[liste_finale])

# %%
df_weather
# Out:
#            DATE  MAX_TEMPERATURE_C  MIN_TEMPERATURE_C  WINDSPEED_MAX_KMH  \
# 0    2019-01-01                  9                  4                 10
# 1    2019-01-02                  8                  5                 18
# 2    2019-01-03                  6                  0                 18
# 3    2019-01-04                  5                 -1                 15
# 4    2019-01-05                  6                 -1                  8
# ..          ...                ...                ...                ...
# 360  2019-12-27                 13                 10                 13
# 361  2019-12-28                 11                  5                 12
# 362  2019-12-29                  9                  2                 11
# 363  2019-12-30                 12                  4                  7
# 364  2019-12-31                 10                  4                 13
#
#      TEMPERATURE_MORNING_C  TEMPERATURE_NOON_C  TEMPERATURE_EVENING_C  \
# 0                        4                   7                      8
# 1                        7                   7                      5
# 2                        0                   4                      3
# 3                       -1                   4                      3
# 4                       -1                   4                      3
# ..                     ...                 ...                    ...
# 360                     10                  12                     11
# 361                      7                   8                      8
# 362                      3                   6                      7
# 363                      5                   9                      9
# 364                      4                   7                      9
#
#      PRECIP_TOTAL_DAY_MM  HUMIDITY_MAX_PERCENT  VISIBILITY_AVG_KM  ...  \
# 0                    0.2                    94              9.000  ...
# 1                    0.0                    90              9.000  ...
# 2                    0.0                    88             10.000  ...
# 3                    0.0                    91             10.000  ...
# 4                    0.0                    91              8.000  ...
# ..                   ...                   ...                ...  ...
# 360                  0.0                    96              7.375  ...
# 361                  0.0                    93              7.625  ...
# 362                  0.0                    86             10.000  ...
# 363                  0.0                    61             10.000  ...
# 364                  0.1                    94              9.000  ...
#
#      TOTAL_SNOW_MM  UV_INDEX  SUNHOUR           OPINION  MONTH  DAY  \
# 0                0         1      5.1          very bad      1    1
# 1                0         1      8.7          very bad      1    2
# 2                0         1      8.7          very bad      1    3
# 3                0         1      5.1          very bad      1    4
# 4                0         1      8.7          very bad      1    5
# ..             ...       ...      ...               ...    ...  ...
# 360              0         1      8.7  not good not bad     12   27
# 361              0         1      6.9          very bad     12   28
# 362              0         1      8.7          very bad     12   29
# 363              0         1      8.7          very bad     12   30
# 364              0         1      8.7          very bad     12   31
#
#      PREDICT_FROM_SUN  PREDICT_FROM_MIN  PREDICT_FROM_BOTH   PREDICT3
# 0           11.396823         10.579999           8.980922   9.083993
# 1           16.020019         11.802741          12.353602   7.796828
# 2           16.020019          5.689031           7.410233   5.902275
# 3           11.396823          4.466289           4.037552   5.353448
# 4           16.020019          4.466289           6.421559   6.169981
# ..                ...               ...                ...        ...
# 360         16.020019         17.916452          17.296971  12.882859
# 361         13.708421         11.802741          11.161599  10.376993
# 362         16.020019          8.134515           9.387580   8.922115
# 363         16.020019         10.579999          11.364928  11.813832
# 364         16.020019         10.579999          11.364928   9.822295
#
# [365 rows x 28 columns]
