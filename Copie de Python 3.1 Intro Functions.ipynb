# %% [markdown]
# # Mission 1

# %% [markdown]
# Create a function that returns the sum of 3 + 3 when executed.
# You must use the `return` statement.

# %%
def addition_sum(num1, num2):

 total = num1 + num2
 return total

addition_sum(3, 3)
# Out:
# 6

# %% [markdown]
# # Mission 2

# %% [markdown]
# Create a function that returns the sum of two numbers.
# The user of the function must be able to sum two numbers of his choice, when the function is executed.
# You must not use `input`.

# %%
def addition_sum(num1, num2):
  num1 = 5
  num2 = 3
  total = num1 + num2
  return total



total = addition_sum(num1, num2)
print(f"The sum of {num1} and {num2} is {total}")
# Out:
# The sum of 5 and 3 is 8

# %% [markdown]
# Question:
# What is a parameter in a function?

# %% [markdown]
# Answer:

# %% [markdown]
# # Mission 3

# %% [markdown]
# Create a function that returns the sum of two numbers chosen by the user of the function, in a sentence.
# For example:
# `new_sum_2(3,8)` returns `"The sum of 3 + 8 is equal to 11."`

# %%
def addition_sum(num1, num2):
  total = num_1 + num_2
  return total

num_1 = int(input("type a number"))
num_2 = int(input("type a number"))

result = addition_sum(num_1, num_2)
print(f"the sum of {num_1} and {num_2} is equal to {result}")

# %% [markdown]
# # Mission 4
#
# Create a function that returns 2 objects when executed:
# * An object that will be the product of two numbers chosen by the user of the function.
# * A word chosen by the user of the function.

# %%
def addition_sum():
  num_1 = int(input("type a number"))
  num_2 = int(input("type a number"))
  user_word = (input("Enter a word: "))

  total = num_1 * num_2

  return (total, user_word)


result = addition_sum()
print(result)
type(result)
# Out:
# type a number4
# type a number5
# Enter a word: oui
# (20, 'oui')
# tuple

# %% [markdown]
# Your result must be two objects that are in brackets.
# This is a tuple.
#
# Question:
# Why is the returned object a tuple that contains two objects?
#
# Answer:

# %% [markdown]
# # Mission 5
#
# Create a function that returns the sum of two numbers when executed.
# Also, your function must return a sentence that simply indicates if the sum of the two numbers chosen by the user is:
# * less than 10
# * between 10 and 50
# * greater than 50
# Again, you must use `return`.

# %%
def addition_sum(num_1, num_2):
  num_1 = int(input("type a number"))
  num_2 = int(input("type a number"))

  total = num_1 + num_2

  if total < 10:
    return(f" the sum of {num_1} and {num_2} is equal to {total}, so below 10")

  elif  10 < total < 50:
    return(f" the sum of {num_1} and {num_2} is equal to {total}, so between 10 and 50")

  else:
    return(f" the sum of {num_1} and {num_2} is equal to {total}, so greater than 50")


result = addition_sum(num_1, num_2)
print(result)
# Out:
# type a number50
# type a number30
#  the sum of 50 and 30 is equal to 80, so greater than 50
