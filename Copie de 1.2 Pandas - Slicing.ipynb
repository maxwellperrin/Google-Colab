# %% [markdown]
# # Mission 1
#
# Display the following information [for this dataset](https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/u.user).
# - The last 5 rows
# - The first 5 rows
# - The type of each column
#
# Note : start coding something by typing `pd.read_csv()` and explore the different options available, especially the `sep` parameter.

# %%
#Il te manque les 5 dernière lignes
#Pour les types : je te conseille la méthode : def_1.dtypes

#Mission 5 :
#Attention pour le premier read_csv tu as un problème de séparateur
#Et remplace Shape par Shape Reported Sinon il ne remplace pas le titre de ta colonne.

#Sinon très bien ! Dis moi quand tu auras corrigé :)

# %%
import pandas as pd

# %%
def_1 = pd.read_csv("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/u.user", sep='|', header=None)
def_1.head()
# Out:
#    0   1  2           3      4
# 0  1  24  M  technician  85711
# 1  2  53  F       other  94043
# 2  3  23  M      writer  32067
# 3  4  24  M  technician  43537
# 4  5  33  F       other  15213

# %%
def_1 = pd.read_csv("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/u.user", sep='|', header=None)
def_1.tail()
# Out:
#        0   1  2              3      4
# 938  939  26  F        student  33319
# 939  940  32  M  administrator  02215
# 940  941  20  M        student  97229
# 941  942  48  F      librarian  78209
# 942  943  22  M        student  77841

# %%
def_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 943 entries, 0 to 942
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       943 non-null    int64
#  1   1       943 non-null    int64
#  2   2       943 non-null    object
#  3   3       943 non-null    object
#  4   4       943 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 37.0+ KB

# %% [markdown]
# # Mission 2
#
# Display the first 10 rows [in the following file](https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/drinks.csv)

# %%
df=pd.read_csv("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/drinks.csv", sep = ',')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
df.iloc[0:10]
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 2            Algeria             25                0             14
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
# 6          Argentina            193               25            221
# 7            Armenia             21              179             11
# 8          Australia            261               72            212
# 9            Austria            279               75            191
#
#    total_litres_of_pure_alcohol      continent
# 0                           0.0           Asia
# 1                           4.9         Europe
# 2                           0.7         Africa
# ...

# %% [markdown]
# Set the "country" column as the index for the dataframe, using `set_index` method.

# %%
df_2 = df.set_index('country')
df_2
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
# ...                    ...              ...            ...
# Venezuela              333              100              3
# Vietnam                111                2              1
# Yemen                    6                0              0
# Zambia                  32               19              4
# Zimbabwe                64               18              4
#
#              total_litres_of_pure_alcohol      continent
# country
# Afghanistan                           0.0           Asia
# Albania                               4.9         Europe
# Algeria                               0.7         Africa
# ...

# %% [markdown]
# # Mission 3
#
# Access the values of the row for **Zimbabwe** (use the index value)

# %%
df_2.loc["Zimbabwe" :]
# Out:
#           beer_servings  spirit_servings  wine_servings  \
# country
# Zimbabwe             64               18              4
#
#           total_litres_of_pure_alcohol continent
# country
# Zimbabwe                           4.7    Africa

# %% [markdown]
# # Mision 4
#
# Display only the "continent" column value for the country **Zimbabwe**.

# %%
df_2.loc["Zimbabwe", "continent" ]
# Out:
# 'Africa'

# %% [markdown]
# # Mission 5
#
# Rename the columns [of this dataset](https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/ufo.csv), try using the following 2 different methods to achieve this:
# - Setting column names directly when reading the file
# - Editing after creating the dataframe ([This resource could be useful](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rename.html))

# %%
tableau_1 = pd.read_csv("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/ufo.csv", sep = ',')
tableau_1
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
import pandas as pd

tableau_2 = pd.read_csv("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/ufo.csv", sep = ',', names =["Ville", "Couleur", "Format", "Etat", "Date"], header=0 )
# Out:
#                       Ville Couleur    Format Etat              Date
# 0                    Ithaca     NaN  TRIANGLE   NY    6/1/1930 22:00
# 1               Willingboro     NaN     OTHER   NJ   6/30/1930 20:00
# 2                   Holyoke     NaN      OVAL   CO   2/15/1931 14:00
# 3                   Abilene     NaN      DISK   KS    6/1/1931 13:00
# 4      New York Worlds Fair     NaN     LIGHT   NY   4/18/1933 19:00
# ...                     ...     ...       ...  ...               ...
# 18236            Grant Park     NaN  TRIANGLE   IL  12/31/2000 23:00
# 18237           Spirit Lake     NaN      DISK   IA  12/31/2000 23:00
# 18238           Eagle River     NaN       NaN   WI  12/31/2000 23:45
# 18239           Eagle River     RED     LIGHT   WI  12/31/2000 23:45
# 18240                  Ybor     NaN      OVAL   FL  12/31/2000 23:59
#
# [18241 rows x 5 columns]

# %%
import pandas as pd
tableau_3 = pd.read_csv("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/ufo.csv", sep = ',')


tableau_3.rename(columns= {"City":"Ville", "Colors Reported":"Couleur", "Shape Reported":"Format","State":"Etat", "Time":"Horaire"})
# Out:
#                       Ville Couleur    Format Etat           Horaire
# 0                    Ithaca     NaN  TRIANGLE   NY    6/1/1930 22:00
# 1               Willingboro     NaN     OTHER   NJ   6/30/1930 20:00
# 2                   Holyoke     NaN      OVAL   CO   2/15/1931 14:00
# 3                   Abilene     NaN      DISK   KS    6/1/1931 13:00
# 4      New York Worlds Fair     NaN     LIGHT   NY   4/18/1933 19:00
# ...                     ...     ...       ...  ...               ...
# 18236            Grant Park     NaN  TRIANGLE   IL  12/31/2000 23:00
# 18237           Spirit Lake     NaN      DISK   IA  12/31/2000 23:00
# 18238           Eagle River     NaN       NaN   WI  12/31/2000 23:45
# 18239           Eagle River     RED     LIGHT   WI  12/31/2000 23:45
# 18240                  Ybor     NaN      OVAL   FL  12/31/2000 23:59
#
# [18241 rows x 5 columns]

# %% [markdown]
# # Mission 6
#
# Select the first 3 rows and all the columns of the dataframe using iloc

# %%
import pandas as pd

tableau_3 = pd.read_csv("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/ufo.csv", sep = ',')


tableau_3.rename(columns= {"City":"Ville", "Colors Reported":"Couleur", "Shape":"Format","State":"Etat", "Time":"Horaire"})

tableau_3.iloc[:3] # je cherche par les index
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %% [markdown]
# # Mission 7
#
# Achieve the same result as in mission 6 by using loc

# %%
tableau_3.loc[:2] # j'utilise les strings avec loc
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00
