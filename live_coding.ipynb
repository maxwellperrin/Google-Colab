# %% [markdown]
# # Importation des bibliothèques

# %%
# Bibliothèques manipulation des données

# %%
import pandas as pd
import numpy as np

# %%
# Bibliothèques de Dataviz

# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot') or plt.style.use('ggplot')

import seaborn as sns
sns.set_style('darkgrid')

import plotly.express as px

# %%
urls = ['https://raw.githubusercontent.com/Phil-BENISSAN/titanic/main/titanic.csv',
        'https://raw.githubusercontent.com/Phil-BENISSAN/titanic/main/titanic_new.csv']

# %%
('https://raw.githubusercontent.com/Phil-BENISSAN/titanic/main/titanic_new.csv').split('/')[-1].split('.')[0]
# Out:
# 'titanic_new'

# %%
for url in urls:
  name = url.split('/')[-1].split('.')[0]
  rows = 'nrows = 50'

  #récupérer des datasets

  print('Chargement en cours...')
  exec(f"df_{name} = pd.read_csv('{url}', {rows})")

print(f'importation ok!')
# Out:
# Chargement en cours...
# Chargement en cours...
# importation ok!

# %%
display(df_titanic.info(), df_titanic_new.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  50 non-null     int64
#  1   Survived     50 non-null     int64
#  2   Pclass       50 non-null     int64
#  3   Name         50 non-null     object
#  4   Sex          50 non-null     object
#  5   Age          36 non-null     float64
#  6   SibSp        50 non-null     int64
#  7   Parch        50 non-null     int64
#  8   Ticket       50 non-null     object
#  9   Fare         50 non-null     float64
#  10  Cabin        9 non-null      object
#  11  Embarked     50 non-null     object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 4.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
# ...

# %%
display(df_titanic.head(3), df_titanic_new.head(3))
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
#    pclass  survived                            name     sex    age  sibsp  \
# 0       1         1   Allen, Miss. Elisabeth Walton  female     29      0
# 1       1         1  Allison, Master. Hudson Trevor    male  0,917      1
# 2       1         0    Allison, Miss. Helen Loraine  female      2      1
#
# ...

# %%
df_titanic_new.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
columns_to_keep =  [['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp','Parch','Fare', 'Cabin'],
                   ['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'fare', 'cabin']]

# %%
for loop in range(len(urls)):
  name = urls[loop].split('/')[-1].split('.')[0]
  rows = 'nrows = 50'

  #récupérer des datasets

  print('Chargement en cours...')
  print(f'{name}')
  exec(f"df_{name} = pd.read_csv('{urls[loop]}', usecols = {columns_to_keep[loop]})")
  print(f'{name} créé')
# Out:
# Chargement en cours...
# titanic
# titanic créé
# Chargement en cours...
# titanic_new
# titanic_new créé

# %%
display(df_titanic.head(3), df_titanic_new.head(3))
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
#
#       Sex   Age  SibSp  Parch     Fare Cabin
# 0    male  22.0      1      0   7.2500   NaN
# 1  female  38.0      1      0  71.2833   C85
# 2  female  26.0      0      0   7.9250   NaN
#    pclass  survived                            name     sex    age  sibsp  \
# 0       1         1   Allen, Miss. Elisabeth Walton  female     29      0
# 1       1         1  Allison, Master. Hudson Trevor    male  0,917      1
# 2       1         0    Allison, Miss. Helen Loraine  female      2      1
#
#    parch    fare    cabin
# 0      0  ######       B5
# 1      2  ######  C22 C26
# 2      2  ######  C22 C26

# %%
df_titanic_new.rename(columns = lambda x : x.title(), inplace = True)

# %%
#df_titanic_new.rename(columns = lambda x : x.lower().title(), inplace = True)

# %%
df_titanic_new
# Out:
#       Pclass  Survived                                             Name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          Sex    Age  Sibsp  Parch     Fare    Cabin
# ...

# %%
list_columns = list(df_titanic_new.columns)

for loop in range(len(list_columns)):
  print(f'traitement de colonne{list_columns[loop]}')
  list_columns[loop] = list_columns[loop].title()

df_titanic_new.columns = list_columns
# Out:
# traitement de colonnePclass
# traitement de colonneSurvived
# traitement de colonneName
# traitement de colonneSex
# traitement de colonneAge
# traitement de colonneSibsp
# traitement de colonneParch
# traitement de colonneFare
# traitement de colonneCabin

# %%
df_titanic_new.rename(columns = {'Sibsp' : 'SibSp'}, inplace = True)

# %%
df_titanic_new = df_titanic_new[['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp','Parch','Fare', 'Cabin']]

# %%
display(df_titanic.head(5), df_titanic_new.head(5))
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch     Fare Cabin
# 0    male  22.0      1      0   7.2500   NaN
# 1  female  38.0      1      0  71.2833   C85
# 2  female  26.0      0      0   7.9250   NaN
# 3  female  35.0      1      0  53.1000  C123
# 4    male  35.0      0      0   8.0500   NaN
#    Survived  Pclass                                             Name     Sex  \
# 0         1       1                    Allen, Miss. Elisabeth Walton  female
# 1         1       1                   Allison, Master. Hudson Trevor    male
# ...

# %%
display(df_titanic.info(), df_titanic_new.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Fare      891 non-null    float64
#  8   Cabin     204 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  1309 non-null   int64
#  1   Pclass    1309 non-null   int64
#  2   Name      1309 non-null   object
#  3   Sex       1309 non-null   object
# ...

# %%
#fig, axes = plt.subplots(figsize = (12, 8), nrows = 2, ncols=2)

sns.histplot(data = df_titanic[df_titanic['Sex'] == 'female'].dropna(), x = 'Survived', hue = 'Survived')
# Out:
# <Axes: xlabel='Survived', ylabel='Count'>

# %%
sns.histplot(data = df_titanic[(df_titanic['Sex'] == 'female') & (df_titanic['Age'].notna())], x = 'Survived', hue = 'Survived')
# Out:
# <Axes: xlabel='Survived', ylabel='Count'>

# %%
fig, axes = plt.subplots(figsize = (12, 8), nrows = 2, ncols=2)

label_all = ('Survived', 'Not survived')

list_graphs = [[df_titanic[(df_titanic['Sex'] == 'female') & (df_titanic['Age'].notna())], axes[0,0], 'Female with age' ],
               [df_titanic[(df_titanic['Sex'] == 'female') & (df_titanic['Age'].isna())], axes[1,0], 'Female with no age'],
               [df_titanic[(df_titanic['Sex'] == 'male') & (df_titanic['Age'].notna())], axes[0,1], 'Male with no age'],
               [df_titanic[(df_titanic['Sex'] == 'male') & (df_titanic['Age'].isna())], axes[1,1], 'Male with no age'],
]
for element in list_graphs:
  ax = sns.histplot(data = element[0], x = 'Survived', hue = 'Survived', ax = element[1], bins= 2)
  ax.legend(label_all)
  ax.set_title(element[2])
  ax.set_xlabel(xlabel=None)

# %%
#!pip install ydata-profiling

# %%
#from ydata_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-28-cadbc1d1f191> in <cell line: 1>()
# ----> 1 from ydata_profiling import ProfileReport
#
# ModuleNotFoundError: No module named 'ydata_profiling'

# %%
# use ProfileReport
#pr_df = ProfileReport(df_titanic)

#show pr

#pr_df

# %%
sns.displot(df_titanic[df_titanic['Age'].notna()], x = 'Age', col ='Sex')

# %%
median_female = df_titanic['Age'][df_titanic['Sex'] == 'female'].median()
median_male = df_titanic['Age'][df_titanic['Sex'] == 'male'].median()
median_total = df_titanic['Age'].median()

print(f'female : {median_female} / male: {median_male} / median_total{median_total}')
# Out:
# female : 27.0 / male: 29.0 / median_total28.0

# %%
gender = ['female', 'male']

for loop in range(len(gender)):
  df_titanic['Age'][(df_titanic['Age'].isna()) & (df_titanic['Sex']== gender[loop])] == \
  df_titanic['Age'][(df_titanic['Age'].isna()) & (df_titanic['Sex']== gender[loop])].apply(lambda x: median_female if loop == 0 else median_male)

# %%
df_titanic['Age'][df_titanic['Sex'] == 'male'].isna().fillna(median_male, inplace = True)

# %%
df_titanic['Age'][df_titanic['Sex'] == 'male']

# %%
df_titanic[df_titanic['Sex'] == 'male'].isna().apply(lambda x : median_male)

# %%
df_titanic_new['Age'] = df_titanic_new['Age'].apply(lambda x : str(x).replace(',','.'))
df_titanic_new['Age'] = df_titanic_new['Age'].astype('float')

# %%
#df_titanic_new['Age'].median()

# %%
df_all = pd.concat([df_titanic, df_titanic_new])

# %%
df_all['Age'] = df_all['Age'].replace(',','.', inplace = True)

# %%
df_all['Age'] = df_all['Age'].astype('float')

# %%
df_all.info()

# %% [markdown]
# # Importation des données

# %% [markdown]
# lien vers titanic.csv :
#
# ```
# https://raw.githubusercontent.com/Phil-BENISSAN/titanic/main/titanic.csv
# ```

# %% [markdown]
# lien vers titanic_new.csv :
#
# ```
# https://raw.githubusercontent.com/Phil-BENISSAN/titanic/main/titanic_new.csv
# ```

# %% [markdown]
# - Ne prendre que les 50 premières lignes afin d'observer les colonnes

# %%
import pandas as pd
df1 = pd.read_csv('https://raw.githubusercontent.com/Phil-BENISSAN/titanic/main/titanic.csv')
df2 = pd.read_csv('https://raw.githubusercontent.com/Phil-BENISSAN/titanic/main/titanic_new.csv')

# %%
df1.info()

# %%
df1.drop(columns = ['PassengerId', 'Parch', 'Ticket','Cabin','Embarked'], inplace = True)

# %%
df1.info()

# %%
df1['Sex'] = df1['Sex'].astype('category', copy =False ).cat.codes

# %%
df1['Sex']

# %%
df1.info()

# %%
df2.info()

# %%
df2.drop(columns = ['parch', 'ticket','cabin','embarked', 'home.dest', 'body', 'boat'], inplace = True)

# %%
df2.info()

# %%
df1

# %%
df2.isna().sum()

# %%
df2.dropna(axis = 0, subset = ["age"], inplace = True )

# %%
df2['sex'] = df2['sex'].astype('category', copy =False ).cat.codes

# %%
df2['age'] = df2['age'].apply(lambda x : float(x.replace(",", ".")) if type(x)==str else int(x))

# %%
df2['fare'] = df2['fare'].apply(lambda x : float(x.replace(",",".")) if (x != '######' and type(x)==str) else x )

# %%
df2['fare'].value_counts()

# %%
display(df2.head(5), df1.head(5))
df2.fare.value_counts()

# %%
dict_rename = {'pclass':'Pclass', 'survived': 'Survived', 'name' : 'Name', 'sex': 'Sex', 'age':'Age', 'ticket': 'Ticket', 'fare' : 'Fare', 'embarked' : 'Embarked', 'sibsp': 'SibSp', 'parch':'Parch', 'cabin':'Cabin'}
df2.rename(columns = dict_rename, inplace = True)

# %%
display(df2.head(5), df1.head(5))

# %% [markdown]
# # ** LE BUT DE CE DOJO EST DE CONCATENER CES DEUX DATASETS **

# %% [markdown]
# # A vous de jouer!

# %%
df = pd.concat([df2, df1])

# %%
len(df[df.duplicated(subset = ['Name'])]['Name'].unique())

# %%
df['Age'] = df['Age'].apply(lambda x : float(x.replace(",", ".")) if type(x)==str else x)

# %%
df['Fare'] = df['Fare'].apply(lambda x : float(x.replace(",",".")) if (x != '######' and type(x)==str) else x )

# %%
df_fare.dropna(axis = 0, subset = ['Fare'], inplace = True)

# %%
df_fare = df[df['Fare'] != '######']

# %% [markdown]
# - Créer un modèle de ML de régression sur le nouveau Dataset

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X = df[['Pclass', 'Sex', 'SibSp']]
y = df['Survived']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42, test_size = 0.15)

model_no_fare = LinearRegression().fit(X_train, y_train)
print(model_no_fare.score(X_train, y_train))
print(model_no_fare.score(X_test, y_test))

# %% [markdown]
# - Est-ce pertinent ?

# %%
X = df_fare[['Pclass', 'Sex', 'SibSp', 'Age', 'Fare']]
y = df_fare['Survived']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42, test_size = 0.25)

model_no_fare = LinearRegression().fit(X_train, y_train)
print(model_no_fare.score(X_train, y_train))
print(model_no_fare.score(X_test, y_test))

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(data = df, 'Age'))
plt.show()

# %%
df
