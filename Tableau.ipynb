# %%
import pandas as pd

# %%
df = pd.read_csv("/content/avia_tf_apal_1_Data.csv")

# %%
df
# Out:
#          TIME REP_AIRP                                     REP_AIRP_LABEL  \
# 0     2017M01  FR_FMCZ                                   DZAOUDZI airport
# 1     2017M01  FR_FMEE                   LA REUNION-ROLAND GARROS airport
# 2     2017M01  FR_FMEP                   SAINT PIERRE PIERREFONDS airport
# 3     2017M01  FR_LFAQ                                ALBERT-BRAY airport
# 4     2017M01  FR_LFAT                    LE TOUQUET-COTE D'OPALE airport
# ...       ...      ...                                                ...
# 2875  2019M08  FR_TFFG       SAINT MARTIN, GRAND CASE, GUADELOUPE airport
# 2876  2019M08  FR_TFFJ           SAINT BARTHELEMY/FRENCH ANTILLES airport
# 2877  2019M08  FR_TFFM                              MARIE GALANTE airport
# 2878  2019M08  FR_TFFR        POINTE-A-PITRE/LE RAIZET/GUADELOUPE airport
# 2879  2019M08  FR_TFFS  LES SAINTES/TERRE DE HAUT/FRENCH ANTILLES airport
#
#      UNIT UNIT_LABEL TRA_MEAS      TRA_MEAS_LABEL AIRLINE AIRLINE_LABEL  \
# ...

# %%
df = df.drop(columns = "Flag and Footnotes")

# %%
df
# Out:
#          TIME REP_AIRP                                     REP_AIRP_LABEL  \
# 0     2017M01  FR_FMCZ                                   DZAOUDZI airport
# 1     2017M01  FR_FMEE                   LA REUNION-ROLAND GARROS airport
# 2     2017M01  FR_FMEP                   SAINT PIERRE PIERREFONDS airport
# 3     2017M01  FR_LFAQ                                ALBERT-BRAY airport
# 4     2017M01  FR_LFAT                    LE TOUQUET-COTE D'OPALE airport
# ...       ...      ...                                                ...
# 2875  2019M08  FR_TFFG       SAINT MARTIN, GRAND CASE, GUADELOUPE airport
# 2876  2019M08  FR_TFFJ           SAINT BARTHELEMY/FRENCH ANTILLES airport
# 2877  2019M08  FR_TFFM                              MARIE GALANTE airport
# 2878  2019M08  FR_TFFR        POINTE-A-PITRE/LE RAIZET/GUADELOUPE airport
# 2879  2019M08  FR_TFFS  LES SAINTES/TERRE DE HAUT/FRENCH ANTILLES airport
#
#      UNIT UNIT_LABEL TRA_MEAS      TRA_MEAS_LABEL AIRLINE AIRLINE_LABEL  \
# ...

# %% [markdown]
# ## Transformation Value en INT

# %%
df['Value'].unique()
# Out:
# array(['29 766', '223 155', '10 418', ..., '174 264', '20 012', '218 883'],
#       dtype=object)

# %%
df.loc[4]
# Out:
# TIME                                      2017M01
# REP_AIRP                                  FR_LFAT
# REP_AIRP_LABEL    LE TOUQUET-COTE D'OPALE airport
# UNIT                                          PAS
# UNIT_LABEL                              Passenger
# TRA_MEAS                                  PAS_CRD
# TRA_MEAS_LABEL                 Passengers carried
# AIRLINE                                     TOTAL
# AIRLINE_LABEL                        All airlines
# Value                                           :
# Name: 4, dtype: object

# %%
df['Value'] = df['Value'].replace(":", "0")

# %%
df['Value']
# Out:
# 0        29 766
# 1       223 155
# 2        10 418
# 3            30
# 4             0
#          ...
# 2875          0
# 2876          0
# 2877          0
# 2878          0
# 2879          0
# Name: Value, Length: 2880, dtype: object

# %%
df['Value'] = df['Value'].str.replace(' ', '')

# %%
df['Value'] = df['Value'].astype(int)

# %%
df['Value'].unique()
# Out:
# array([ 29766, 223155,  10418, ..., 174264,  20012, 218883])

# %% [markdown]
# ## Transformation colonne Time en dateTime

# %%
df['TIME'] = df['TIME'].str.replace('M', '-')

# %%
df['TIME']
# Out:
# 0       2017-01
# 1       2017-01
# 2       2017-01
# 3       2017-01
# 4       2017-01
#          ...
# 2875    2019-08
# 2876    2019-08
# 2877    2019-08
# 2878    2019-08
# 2879    2019-08
# Name: TIME, Length: 2880, dtype: object

# %%
df['TIME'] = pd.to_datetime(df['TIME'], format='%Y-%m')

# %%
df['TIME']
# Out:
# 0      2017-01-01
# 1      2017-01-01
# 2      2017-01-01
# 3      2017-01-01
# 4      2017-01-01
#           ...
# 2875   2019-08-01
# 2876   2019-08-01
# 2877   2019-08-01
# 2878   2019-08-01
# 2879   2019-08-01
# Name: TIME, Length: 2880, dtype: datetime64[ns]

# %%
#df['Year'] = df['TIME'].dt.year

# %%
df['TIME']
# Out:
# 0      2017-01-01
# 1      2017-01-01
# 2      2017-01-01
# 3      2017-01-01
# 4      2017-01-01
#           ...
# 2875   2019-08-01
# 2876   2019-08-01
# 2877   2019-08-01
# 2878   2019-08-01
# 2879   2019-08-01
# Name: TIME, Length: 2880, dtype: datetime64[ns]

# %%
#df['Year']

# %%
#df['Month']= df['TIME'].dt.month

# %%
#df['Month']

# %%
#df = df.drop(columns = "TIME")

# %%
df
# Out:
#            TIME REP_AIRP                                     REP_AIRP_LABEL  \
# 0    2017-01-01  FR_FMCZ                                   DZAOUDZI airport
# 1    2017-01-01  FR_FMEE                   LA REUNION-ROLAND GARROS airport
# 2    2017-01-01  FR_FMEP                   SAINT PIERRE PIERREFONDS airport
# 3    2017-01-01  FR_LFAQ                                ALBERT-BRAY airport
# 4    2017-01-01  FR_LFAT                    LE TOUQUET-COTE D'OPALE airport
# ...         ...      ...                                                ...
# 2875 2019-08-01  FR_TFFG       SAINT MARTIN, GRAND CASE, GUADELOUPE airport
# 2876 2019-08-01  FR_TFFJ           SAINT BARTHELEMY/FRENCH ANTILLES airport
# 2877 2019-08-01  FR_TFFM                              MARIE GALANTE airport
# 2878 2019-08-01  FR_TFFR        POINTE-A-PITRE/LE RAIZET/GUADELOUPE airport
# 2879 2019-08-01  FR_TFFS  LES SAINTES/TERRE DE HAUT/FRENCH ANTILLES airport
#
# ...

# %%
nbr_valeur = df['Value'].value_counts()

# %%
nbr_valeur_pourcentage = (nbr_valeur / len(df['Value'])) * 100
missing_table = pd.DataFrame({'Valeur': nbr_valeur, 'Percentage': nbr_valeur_pourcentage })
print(missing_table)
# Out:
#         Valeur  Percentage
# 0          990   34.375000
# 7929         2    0.069444
# 165          2    0.069444
# 11206        2    0.069444
# 20161        2    0.069444
# ...        ...         ...
# 14672        1    0.034722
# 4997         1    0.034722
# 4653         1    0.034722
# 7683         1    0.034722
# 218883       1    0.034722
#
# [1866 rows x 2 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(df)

# %%
#from google.colab import drive

# %%
from google.colab import files

# %%
df.to_csv('aviation.csv', sep=',', index=False)

# %%
df.columns
# Out:
# Index(['TIME', 'REP_AIRP', 'REP_AIRP_LABEL', 'UNIT', 'UNIT_LABEL', 'TRA_MEAS',
#        'TRA_MEAS_LABEL', 'AIRLINE', 'AIRLINE_LABEL', 'Value'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2880 entries, 0 to 2879
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   TIME            2880 non-null   datetime64[ns]
#  1   REP_AIRP        2880 non-null   object
#  2   REP_AIRP_LABEL  2880 non-null   object
#  3   UNIT            2880 non-null   object
#  4   UNIT_LABEL      2880 non-null   object
#  5   TRA_MEAS        2880 non-null   object
#  6   TRA_MEAS_LABEL  2880 non-null   object
#  7   AIRLINE         2880 non-null   object
#  8   AIRLINE_LABEL   2880 non-null   object
#  9   Value           2880 non-null   int64
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 225.1+ KB

# %%
df_1 = pd.read_csv('/content/aviation.csv')
df_1
# Out:
#             TIME REP_AIRP                                     REP_AIRP_LABEL  \
# 0     2017-01-01  FR_FMCZ                                   DZAOUDZI airport
# 1     2017-01-01  FR_FMEE                   LA REUNION-ROLAND GARROS airport
# 2     2017-01-01  FR_FMEP                   SAINT PIERRE PIERREFONDS airport
# 3     2017-01-01  FR_LFAQ                                ALBERT-BRAY airport
# 4     2017-01-01  FR_LFAT                    LE TOUQUET-COTE D'OPALE airport
# ...          ...      ...                                                ...
# 2875  2019-08-01  FR_TFFG       SAINT MARTIN, GRAND CASE, GUADELOUPE airport
# 2876  2019-08-01  FR_TFFJ           SAINT BARTHELEMY/FRENCH ANTILLES airport
# 2877  2019-08-01  FR_TFFM                              MARIE GALANTE airport
# 2878  2019-08-01  FR_TFFR        POINTE-A-PITRE/LE RAIZET/GUADELOUPE airport
# 2879  2019-08-01  FR_TFFS  LES SAINTES/TERRE DE HAUT/FRENCH ANTILLES airport
#
# ...

# %%
df_1['REP_AIRP_LABEL'].unique()
# Out:
# array(['DZAOUDZI airport', 'LA REUNION-ROLAND GARROS airport',
#        'SAINT PIERRE PIERREFONDS airport', 'ALBERT-BRAY airport',
#        "LE TOUQUET-COTE D'OPALE airport", 'AGEN-LA GARENNE airport',
#        'BORDEAUX-MERIGNAC airport', 'BERGERAC-ROUMANIERE airport',
#        'LA ROCHELLE-ILE DE RE airport', 'POITIERS-BIARD airport',
#        'LIMOGES-BELLEGARDE airport', 'TOULOUSE/BLAGNAC airport',
#        'PAU-PYRENEES airport', 'TARBES LOURDES PYRENEES airport',
#        'ANGOULEME-BRIE-CHAMPNIERS airport', 'BRIVE/LA ROCHE airport',
#        'PERIGEUX-BASSILLAC airport', 'BIARRITZ-PAYS BASQUE airport',
#        'CASTRES MAZAMET airport', 'RODEZ-AVEYRON airport',
#        'ROCHEFORT-CHARENTE-MARITIME airport', 'OUESSANT airport',
#        'DOLE-TAVAUX airport', 'LE PUY-LOUDES airport',
#        'METZ NANCY-LORRAINE airport', 'ANGERS MARCE airport',
#        'BASTIA-PORETTA airport', 'CALVI-SAINTE-CATHERINE airport',
# ...

# %%
#df_1 = df_1.drop(columns = "Unnamed: 0" )

# %%
#df_1

# %%
airport = pd.read_csv("https://davidmegginson.github.io/ourairports-data/airports.csv")

# %%
airport
# Out:
#            id    ident           type                       name  \
# 0        6523      00A       heliport          Total RF Heliport
# 1      323361     00AA  small_airport       Aero B Ranch Airport
# 2        6524     00AK  small_airport               Lowell Field
# 3        6525     00AL  small_airport               Epps Airpark
# 4      506791     00AN  small_airport       Katmai Lodge Airport
# ...       ...      ...            ...                        ...
# 78203   46378  ZZ-0001       heliport            Sealand Helipad
# 78204  307326  ZZ-0002  small_airport  Glorioso Islands Airstrip
# 78205  346788  ZZ-0003  small_airport      Fainting Goat Airport
# 78206  342102     ZZZW         closed     Scandium City Heliport
# 78207  313629     ZZZZ  small_airport     Satsuma Iōjima Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 0         40.070985     -74.933689          11.0       NaN          US
# ...

# %%
airport['type'].unique()
# Out:
# array(['heliport', 'small_airport', 'closed', 'seaplane_base',
#        'balloonport', 'medium_airport', 'large_airport'], dtype=object)

# %%
airport = airport[airport['type'].isin(['small_airport', 'medium_airport', 'large_airport'])]

# %%
airport = airport.drop(columns=['continent', 'id', 'elevation_ft', 'municipality', 'scheduled_service', 'iata_code', 'wikipedia_link', 'keywords'], errors='ignore')

# %%
airport
# Out:
#          ident            type                       name  latitude_deg  \
# 1         00AA   small_airport       Aero B Ranch Airport     38.704022
# 2         00AK   small_airport               Lowell Field     59.947733
# 3         00AL   small_airport               Epps Airpark     34.864799
# 4         00AN   small_airport       Katmai Lodge Airport     59.093287
# 6         00AS   small_airport             Fulton Airport     34.942803
# ...        ...             ...                        ...           ...
# 78201     ZYYK  medium_airport      Yingkou Lanqi Airport     40.542524
# 78202     ZYYY  medium_airport    Shenyang Dongta Airport     41.784401
# 78204  ZZ-0002   small_airport  Glorioso Islands Airstrip    -11.584278
# 78205  ZZ-0003   small_airport      Fainting Goat Airport     32.110587
# 78207     ZZZZ   small_airport     Satsuma Iōjima Airport     30.784722
#
#        longitude_deg iso_country iso_region gps_code local_code home_link  \
# ...
