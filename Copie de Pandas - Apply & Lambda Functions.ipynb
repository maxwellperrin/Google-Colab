# %%
import pandas as pd

# %% [markdown]
# ### Welcome to the Apply Challenge

# %%
link = 'https://raw.githubusercontent.com/chriszapp/datasets/main/books.csv'
books = pd.read_csv(link, nrows = 13)
books.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 2                J.K. Rowling            4.42  0439554896  9780439554893
# 3  J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
# 4  J.K. Rowling/Mary GrandPré            4.78  0439682584  9780439682589
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
# 1           eng          870        2153167               29221
# 2           eng          352           6333                 244
# 3           eng          435        2339585               36325
# 4           eng         2690          41428                 164
#
#   publication_date        publisher
# 0        9/16/2006  Scholastic Inc.
# 1         9/1/2004  Scholastic Inc.
# 2        11/1/2003       Scholastic
# 3         5/1/2004  Scholastic Inc.
# 4        9/13/2004       Scholastic

# %%
# Firstly, have a look at the dataset

# %%
# Mission 1: use apply to create a new column called 'reviews_opinion': if the ratings is between 4.5 and 5, the reviews_opinion is 'very good';
# if the rating is between 4 and 4.5, the reviews_opinion is 'good'; if the rating is between 3 and 4, the reviews_opinions will be 'neutral';
# if the rating is up to 3 the reviews_opinion is going to be 'bad'

# Add your code here




def new_reviews(average_rating):


  if 4.5 < average_rating < 5:
    return 'very good'
  elif 4 < average_rating < 4.5:
    return 'good'
  elif 3 < average_rating < 4:
    return 'neutral'
  else:
    average_rating > 3
  return 'bad'

books['reviews_opinion'] = books['average_rating'].apply(new_reviews)
#books




#isnul = vide
#isna = \na (valeur ? )

#fonction try / except

# %%
# Mission 2: using apply with a function, create a column with the number of authors per book
# (note that in the column 'authors', each name of the author is divided with the character '/')

# Add your code here

def count_authors(authors):

  return len(authors.split('/'))



books['number of authors per book'] = books['authors'].apply(count_authors)
#books

# %%
# Mission 3: rewrite the same task as Mission 2 using the lamdba function

# Add your code here
books['number of authors per book'] = books['authors'].apply(lambda authors: len(authors.split('/')))
#books

# %%
# Mission 4: create a column 'comment_ration'.
# Use the columns 'ratings_count' and 'text_reviews_count' to calculate the percentage of how many text review per reviews are per book:
# percentage = text / reviews * 100
# Use the mathematical operations between columns

# Add your code here


books['comment_ration'] = books['ratings_count']/books['text_reviews_count']*100

# %%
# Mission 5: obtain the same result of Mission 4 using apply with a function.
# Try both methods to apply to the whole dataset and apply to selected columns

# Add your code here

def comment_ration(percentage):
  ratings_count = percentage[0]
  text_reviews_count = percentage[1]

  return (ratings_count/text_reviews_count)* 100

books['comment_ration2'] = books[['text_reviews_count','ratings_count']].apply(comment_ration, axis=1)

# %%
def comment_ration(percentage):
  ratings_count = percentage['ratings_count']
  text_reviews_count = percentage['text_reviews_count']

  return (ratings_count/text_reviews_count)* 100
#books['comment_ratio3'] = (books['text_reviews_count'] / books['ratings_count']) * 100
books['comment_ration3'] = books[['text_reviews_count','ratings_count']].apply(comment_ration, axis=1)

# %%
def comment(percentage):

   return percentage['ratings_count']/ percentage['text_reviews_count']*100

books['comment_ration'] = books.apply(comment, axis = 1)

# %%
# Mission 6: obtain the same result of Mission 5 using apply lambda
# Try both methods to apply to the whole dataset and apply to selected columns




# Add your code here

books['comment_ration'] = books.apply(lambda percentage: (percentage['ratings_count']/percentage['text_reviews_count'])*100, axis = 1)
books
# Out:
#     bookID                                              title  \
# 0        1  Harry Potter and the Half-Blood Prince (Harry ...
# 1        2  Harry Potter and the Order of the Phoenix (Har...
# 2        4  Harry Potter and the Chamber of Secrets (Harry...
# 3        5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4        8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# 5        9  Unauthorized Harry Potter Book Seven News: "Ha...
# 6       10       Harry Potter Collection (Harry Potter  #1-6)
# 7       12  The Ultimate Hitchhiker's Guide: Five Complete...
# 8       13  The Ultimate Hitchhiker's Guide to the Galaxy ...
# 9       14  The Hitchhiker's Guide to the Galaxy (Hitchhik...
# 10      16  The Hitchhiker's Guide to the Galaxy (Hitchhik...
# 11      18  The Ultimate Hitchhiker's Guide (Hitchhiker's ...
# 12      21               A Short History of Nearly Everything
#
#                        authors  average_rating        isbn         isbn13  \
# 0   J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1   J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 2                 J.K. Rowling            4.42  0439554896  9780439554893
# 3   J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
# 4   J.K. Rowling/Mary GrandPré            4.78  0439682584  9780439682589
# 5       W. Frederick Zimmerman            3.74  0976540606  9780976540601
# 6                 J.K. Rowling            4.73  0439827604  9780439827607
# 7                Douglas Adams            4.38  0517226952  9780517226957
# 8                Douglas Adams            4.38  0345453743  9780345453747
# 9                Douglas Adams            4.22  1400052920  9781400052929
# 10   Douglas Adams/Stephen Fry            4.22  0739322206  9780739322208
# 11               Douglas Adams            4.38  0517149257  9780517149256
# 12                 Bill Bryson            4.21  076790818X  9780767908184
#
#    language_code    num_pages  ratings_count  text_reviews_count  \
# 0            eng          652        2095690               27591
# 1            eng          870        2153167               29221
# 2            eng          352           6333                 244
# 3            eng          435        2339585               36325
# 4            eng         2690          41428                 164
# 5          en-US          152             19                   1
# 6            eng         3342          28242                 808
# 7            eng          815           3628                 254
# 8            eng          815         249558                4080
# 9            eng          215           4930                 460
# 10           eng            6           1266                 253
# 11           eng          815           2877                 195
# 12           eng          544         248558                9396
#
#    publication_date           publisher reviews_opinion  \
# 0         9/16/2006     Scholastic Inc.       very good
# 1          9/1/2004     Scholastic Inc.            good
# 2         11/1/2003          Scholastic            good
# 3          5/1/2004     Scholastic Inc.       very good
# 4         9/13/2004          Scholastic       very good
# 5         4/26/2005        Nimble Books         neutral
# 6         9/12/2005          Scholastic       very good
# 7         11/1/2005      Gramercy Books            good
# 8         4/30/2002       Del Rey Books            good
# 9          8/3/2004               Crown            good
# 10        3/23/2005  Random House Audio            good
# 11        1/17/1996         Wings Books            good
# 12        9/14/2004      Broadway Books            good
#
#     number of authors per book  comment_ration
# 0                            2     7595.556522
# 1                            2     7368.560282
# 2                            1     2595.491803
# 3                            2     6440.701996
# 4                            2    25260.975610
# 5                            1     1900.000000
# 6                            1     3495.297030
# 7                            1     1428.346457
# 8                            1     6116.617647
# 9                            1     1071.739130
# 10                           2      500.395257
# 11                           1     1475.384615
# 12                           1     2645.359728

# %%
# Mission 7: extract the year from the publication_date column. How many years of publications are recorded in this dataset? Which are them?
from datetime import datetime as dt

# Add your code here
books['publication_date'] = pd.to_datetime(books['publication_date'])

books['year'] = books['publication_date'].dt.year


print(f'il y a {len(books["year"].unique())} année différente :' )
print(books['year'].unique())
# Out:
# il y a 6 année différente :
# [2006 2004 2003 2005 2002 1996]
