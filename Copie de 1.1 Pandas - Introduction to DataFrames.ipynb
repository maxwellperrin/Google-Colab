# %% [markdown]
# # Mission 1
#
# ![](https://i.imgur.com/Ax3pp2A.png)
#
#
# Create a "fruit" dataframe that reflects the above example **using a list** data structure
#
# [This resource could help you](https://datatofish.com/list-to-dataframe/).

# %%
import pandas as pd

# %%
data = [[30, 21], [20, 12]]

df = pd.DataFrame(data, columns =['Apples', 'Bananas'])

df
# Out:
#    Apples  Bananas
# 0      30       21
# 1      20       12

# %% [markdown]
# # Mission 2
#
# Create a "fruit_vendors" dataframe that reflects the below example **using a dictionary** data structure
#
# ![](https://i.imgur.com/CHPn7ZF.png)
#
# [This resource could help you.](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.from_dict.html)

# %%
data = {"2017 Sales": [35, 21], "2018 Sales": [41, 34]}

df = pd.DataFrame.from_dict(data, orient = 'index', columns=['Apples','Bananas'] )
df
# Out:
#             Apples  Bananas
# 2017 Sales      35       21
# 2018 Sales      41       34

# %%
data = {
    'Apples': [35, 41],
    'Bananas': [21, 34]
}

df = pd.DataFrame(data, index=['2017 Sales', '2018 Sales'])
df
# Out:
#             Apples  Bananas
# 2017 Sales      35       21
# 2018 Sales      41       34

# %% [markdown]
# # Mission 3
#
# Use a loop to display the values from each column in the dataframe from mission 2.

# %%
for name in df.columns:
  print(name)
  for integer in df[name]:
    print(integer)
# Out:
# Apples
# 35
# 41
# Bananas
# 21
# 34

# %% [markdown]
# # Mission 4
#
# Delete the first row of the dataframe from mission 2
#
# [This resource could help you.](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html)

# %%
data = {"2017 Sales": [35, 21], "2018 Sales": [41, 34]}

df = pd.DataFrame.from_dict(data, orient = 'index', columns=['Apples','Bananas'] )

df
# Out:
#             Apples  Bananas
# 2017 Sales      35       21
# 2018 Sales      41       34

# %%
df.drop('2017 Sales', inplace = True)
df
# Out:
#             Apples  Bananas
# 2018 Sales      41       34

# %% [markdown]
# # Mission 5
#
# Delete the first column from the dataframe from mission 2.

# %%
df.drop(columns = 'Apples', inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f4a814e29079> in <cell line: 1>()
# ----> 1 df.drop(columns = 'Apples', inplace = True)
#
# NameError: name 'df' is not defined
